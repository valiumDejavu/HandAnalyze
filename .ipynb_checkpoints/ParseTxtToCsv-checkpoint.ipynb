# %%
import re
import sys
import codecs
import csv




# the file path
pathRead='C:\data\data.txt'
pathWrite='C:\data\output.csv'

# read the txt file
infile=codecs.open(pathRead,'r','utf-8')
outfile = open('csvfile.csv','w')
copy = False
handsNumber=1
for line in infile:
    #print ("Entering the loop")
    if line.startswith("Table"):
            #print ("copy is now true")
            copy = True
    if line.startswith("PokerStars"):
            handsNumber=handsNumber+1
            copy = False
            #print (copy)
    if copy:
            print(line)
              
    if copy==False:
        print('false')
# Out:
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: steepfell ($10 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 3: xata2204 ($8.05 in chips)
#
# Seat 4: DiarioMan ($29.75 in chips)
#
# Seat 5: aspire8_svk ($10.79 in chips)
#
# Seat 6: Cendman ($15.40 in chips)
#
# steepfell: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Kh Jd]
#
# xata2204: folds
#
# DiarioMan: raises $0.24 to $0.34
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.24) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell (small blind) folded before Flop
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 3: xata2204 folded before Flop (didn't bet)
#
# Seat 4: DiarioMan collected ($0.25)
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: steepfell ($10 in chips)
#
# Seat 2: jjpokerfun ($9.90 in chips)
#
# Seat 3: xata2204 ($8.05 in chips)
#
# Seat 4: DiarioMan ($29.90 in chips)
#
# Seat 5: aspire8_svk ($10.79 in chips)
#
# Seat 6: Cendman ($15.40 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# xata2204: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [4c 7s]
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: raises $0.12 to $0.22
#
# jjpokerfun: folds
#
# xata2204: folds
#
# Uncalled bet ($0.12) returned to steepfell
#
# steepfell collected $0.25 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell (button) collected ($0.25)
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 3: xata2204 (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: steepfell ($10.15 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 3: xata2204 ($7.95 in chips)
#
# Seat 4: DiarioMan ($29.90 in chips)
#
# Seat 5: aspire8_svk ($10.79 in chips)
#
# Seat 6: Cendman ($15.40 in chips)
#
# xata2204: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [4d Qd]
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: raises $0.15 to $0.25
#
# jjpokerfun: folds
#
# xata2204: folds
#
# DiarioMan: calls $0.15
#
# *** FLOP *** [Kc 5c 7s]
#
# DiarioMan: checks
#
# steepfell: checks
#
# *** TURN *** [Kc 5c 7s] [Ah]
#
# DiarioMan: checks
#
# steepfell: bets $0.35
#
# DiarioMan: folds
#
# Uncalled bet ($0.35) returned to steepfell
#
# steepfell collected $0.53 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.55 | Rake $0.02
#
# Board [Kc 5c 7s Ah]
#
# Seat 1: steepfell collected ($0.53)
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 3: xata2204 (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) folded on the Turn
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #3 is the button
#
# Seat 1: steepfell ($10.43 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 3: xata2204 ($7.90 in chips)
#
# Seat 4: DiarioMan ($29.65 in chips)
#
# Seat 5: aspire8_svk ($10.79 in chips)
#
# Seat 6: Cendman ($15.40 in chips)
#
# DiarioMan: posts small blind $0.05
#
# aspire8_svk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Ad 7h]
#
# Cendman: folds
#
# steepfell: folds
#
# jjpokerfun: raises $0.20 to $0.30
#
# xata2204: folds
#
# DiarioMan: folds
#
# aspire8_svk: calls $0.20
#
# *** FLOP *** [4s 9s 6d]
#
# aspire8_svk: checks
#
# jjpokerfun: bets $0.34
#
# aspire8_svk: folds
#
# Uncalled bet ($0.34) returned to jjpokerfun
#
# jjpokerfun collected $0.62 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.65 | Rake $0.03
#
# Board [4s 9s 6d]
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun collected ($0.62)
#
# Seat 3: xata2204 (button) folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (small blind) folded before Flop
#
# Seat 5: aspire8_svk (big blind) folded on the Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: steepfell ($10.43 in chips)
#
# Seat 2: jjpokerfun ($10.32 in chips)
#
# Seat 3: xata2204 ($7.90 in chips)
#
# Seat 4: DiarioMan ($29.60 in chips)
#
# Seat 5: aspire8_svk ($10.49 in chips)
#
# Seat 6: Cendman ($15.40 in chips)
#
# aspire8_svk: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [9h As]
#
# steepfell: folds
#
# jjpokerfun: folds
#
# xata2204: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# aspire8_svk: folds
#
# Cendman: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 3: xata2204 folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) collected ($0.25)
#
# Seat 5: aspire8_svk (small blind) folded before Flop
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: steepfell ($10.43 in chips)
#
# Seat 2: jjpokerfun ($10.32 in chips)
#
# Seat 3: xata2204 ($7.90 in chips)
#
# Seat 4: DiarioMan ($29.75 in chips)
#
# Seat 5: aspire8_svk ($10.44 in chips)
#
# Seat 6: Cendman ($15.30 in chips)
#
# Cendman: posts small blind $0.05
#
# steepfell: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [6d 8s]
#
# jjpokerfun: folds
#
# xata2204: raises $0.15 to $0.25
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: raises $0.65 to $0.90
#
# xata2204: raises $1.85 to $2.75
#
# steepfell: calls $1.85
#
# *** FLOP *** [2d 5d 5c]
#
# steepfell: checks
#
# xata2204: bets $5.15 and is all-in
#
# steepfell: calls $5.15
#
# *** TURN *** [2d 5d 5c] [Kd]
#
# *** RIVER *** [2d 5d 5c Kd] [Ac]
#
# *** SHOW DOWN ***
#
# steepfell: shows [As Ah] (a full house, Aces full of Fives)
#
# xata2204: shows [Ks Qs] (two pair, Kings and Fives)
#
# steepfell collected $15.14 from pot
#
# *** SUMMARY ***
#
# Total pot $15.85 | Rake $0.71
#
# Board [2d 5d 5c Kd Ac]
#
# Seat 1: steepfell (big blind) showed [As Ah] and won ($15.14) with a full house, Aces full of Fives
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 3: xata2204 showed [Ks Qs] and lost with two pair, Kings and Fives
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk (button) folded before Flop (didn't bet)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: steepfell ($17.67 in chips)
#
# Seat 2: jjpokerfun ($10.32 in chips)
#
# Seat 4: DiarioMan ($29.75 in chips)
#
# Seat 5: aspire8_svk ($10.44 in chips)
#
# Seat 6: Cendman ($15.25 in chips)
#
# steepfell: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Kd 6h]
#
# DiarioMan: folds
#
# aspire8_svk: raises $0.20 to $0.30
#
# Cendman: folds
#
# steepfell: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.20) returned to aspire8_svk
#
# aspire8_svk collected $0.25 from pot
#
# aspire8_svk: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell (small blind) folded before Flop
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk collected ($0.25)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: steepfell ($17.62 in chips)
#
# Seat 2: jjpokerfun ($10.22 in chips)
#
# Seat 3: xata2204 ($5.24 in chips)
#
# Seat 4: DiarioMan ($29.75 in chips)
#
# Seat 5: aspire8_svk ($10.59 in chips)
#
# Seat 6: Cendman ($15.25 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# xata2204: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Js Qc]
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: raises $0.12 to $0.22
#
# jjpokerfun: raises $0.78 to $1
#
# xata2204: folds
#
# steepfell: calls $0.78
#
# *** FLOP *** [3d 8d Ks]
#
# jjpokerfun: bets $1.10
#
# steepfell: folds
#
# Uncalled bet ($1.10) returned to jjpokerfun
#
# jjpokerfun collected $2.01 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $2.10 | Rake $0.09
#
# Board [3d 8d Ks]
#
# Seat 1: steepfell (button) folded on the Flop
#
# Seat 2: jjpokerfun (small blind) collected ($2.01)
#
# Seat 3: xata2204 (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: steepfell ($16.62 in chips)
#
# Seat 2: jjpokerfun ($11.23 in chips)
#
# Seat 3: xata2204 ($5.14 in chips)
#
# Seat 4: DiarioMan ($29.75 in chips)
#
# Seat 5: aspire8_svk ($10.59 in chips)
#
# Seat 6: Cendman ($15.25 in chips)
#
# xata2204: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8h 3d]
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: raises $0.15 to $0.25
#
# jjpokerfun: folds
#
# xata2204: folds
#
# DiarioMan: calls $0.15
#
# *** FLOP *** [2c 5h 4h]
#
# DiarioMan: checks
#
# steepfell: checks
#
# *** TURN *** [2c 5h 4h] [2s]
#
# DiarioMan: checks
#
# steepfell: checks
#
# *** RIVER *** [2c 5h 4h 2s] [6h]
#
# DiarioMan: checks
#
# steepfell: checks
#
# *** SHOW DOWN ***
#
# DiarioMan: shows [8c Tc] (a pair of Deuces)
#
# steepfell: shows [Kh Qs] (a pair of Deuces - King kicker)
#
# steepfell collected $0.53 from pot
#
# *** SUMMARY ***
#
# Total pot $0.55 | Rake $0.02
#
# Board [2c 5h 4h 2s 6h]
#
# Seat 1: steepfell showed [Kh Qs] and won ($0.53) with a pair of Deuces
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 3: xata2204 (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) showed [8c Tc] and lost with a pair of Deuces
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #3 is the button
#
# Seat 1: steepfell ($16.90 in chips)
#
# Seat 2: jjpokerfun ($11.23 in chips)
#
# Seat 3: xata2204 ($5.09 in chips)
#
# Seat 4: DiarioMan ($29.50 in chips)
#
# Seat 5: aspire8_svk ($10.59 in chips)
#
# Seat 6: Cendman ($15.25 in chips)
#
# DiarioMan: posts small blind $0.05
#
# aspire8_svk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [4c 9c]
#
# Cendman: folds
#
# steepfell: folds
#
# jjpokerfun: raises $0.20 to $0.30
#
# xata2204: folds
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Uncalled bet ($0.20) returned to jjpokerfun
#
# jjpokerfun collected $0.25 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun collected ($0.25)
#
# Seat 3: xata2204 (button) folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (small blind) folded before Flop
#
# Seat 5: aspire8_svk (big blind) folded before Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: steepfell ($16.90 in chips)
#
# Seat 2: jjpokerfun ($11.38 in chips)
#
# Seat 3: xata2204 ($5.09 in chips)
#
# Seat 4: DiarioMan ($29.45 in chips)
#
# Seat 5: aspire8_svk ($10.49 in chips)
#
# Seat 6: Cendman ($15.25 in chips)
#
# aspire8_svk: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [3c Qh]
#
# steepfell: folds
#
# jjpokerfun: folds
#
# xata2204: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# aspire8_svk: folds
#
# Cendman: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 3: xata2204 folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) collected ($0.25)
#
# Seat 5: aspire8_svk (small blind) folded before Flop
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: steepfell ($16.90 in chips)
#
# Seat 2: jjpokerfun ($11.38 in chips)
#
# Seat 3: xata2204 ($5.09 in chips)
#
# Seat 4: DiarioMan ($29.60 in chips)
#
# Seat 5: aspire8_svk ($10.44 in chips)
#
# Seat 6: Cendman ($15.15 in chips)
#
# Cendman: posts small blind $0.05
#
# steepfell: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [5d Ah]
#
# jjpokerfun: folds
#
# xata2204: folds
#
# DiarioMan: raises $0.19 to $0.29
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: calls $0.19
#
# *** FLOP *** [8c Qs 7d]
#
# steepfell: checks
#
# DiarioMan: checks
#
# *** TURN *** [8c Qs 7d] [5h]
#
# steepfell: bets $0.40
#
# DiarioMan: folds
#
# Uncalled bet ($0.40) returned to steepfell
#
# steepfell collected $0.60 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.63 | Rake $0.03
#
# Board [8c Qs 7d 5h]
#
# Seat 1: steepfell (big blind) collected ($0.60)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 3: xata2204 folded before Flop (didn't bet)
#
# Seat 4: DiarioMan folded on the Turn
#
# Seat 5: aspire8_svk (button) folded before Flop (didn't bet)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: steepfell ($17.21 in chips)
#
# Seat 2: jjpokerfun ($11.38 in chips)
#
# Seat 3: xata2204 ($5.09 in chips)
#
# Seat 4: DiarioMan ($29.31 in chips)
#
# Seat 5: aspire8_svk ($10.44 in chips)
#
# Seat 6: Cendman ($15.10 in chips)
#
# steepfell: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8c 9h]
#
# xata2204 has timed out
#
# xata2204: folds
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: folds
#
# Uncalled bet ($0.05) returned to jjpokerfun
#
# jjpokerfun collected $0.10 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.10 | Rake $0
#
# Seat 1: steepfell (small blind) folded before Flop
#
# Seat 2: jjpokerfun (big blind) collected ($0.10)
#
# Seat 3: xata2204 folded before Flop (didn't bet)
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: steepfell ($17.16 in chips)
#
# Seat 2: jjpokerfun ($11.43 in chips)
#
# Seat 4: DiarioMan ($29.31 in chips)
#
# Seat 5: aspire8_svk ($10.44 in chips)
#
# Seat 6: Cendman ($15.10 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [9s Tc]
#
# aspire8_svk: raises $0.20 to $0.30
#
# Cendman: calls $0.30
#
# steepfell: folds
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# *** FLOP *** [Js As 2d]
#
# aspire8_svk: checks
#
# Cendman: checks
#
# *** TURN *** [Js As 2d] [6h]
#
# aspire8_svk: bets $0.50
#
# Cendman: raises $1 to $1.50
#
# aspire8_svk: calls $1
#
# *** RIVER *** [Js As 2d 6h] [Ad]
#
# aspire8_svk: checks
#
# Cendman: bets $3
#
# aspire8_svk: calls $3
#
# *** SHOW DOWN ***
#
# Cendman: shows [2h Ah] (a full house, Aces full of Deuces)
#
# aspire8_svk: mucks hand
#
# Cendman collected $9.31 from pot
#
# *** SUMMARY ***
#
# Total pot $9.75 | Rake $0.44
#
# Board [Js As 2d 6h Ad]
#
# Seat 1: steepfell (button) folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) folded before Flop
#
# Seat 5: aspire8_svk mucked [Qd Ac]
#
# Seat 6: Cendman showed [2h Ah] and won ($9.31) with a full house, Aces full of Deuces
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: steepfell ($17.16 in chips)
#
# Seat 2: jjpokerfun ($11.38 in chips)
#
# Seat 4: DiarioMan ($29.21 in chips)
#
# Seat 5: aspire8_svk ($10 in chips)
#
# Seat 6: Cendman ($19.61 in chips)
#
# DiarioMan: posts small blind $0.05
#
# aspire8_svk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [3d Qd]
#
# Cendman: folds
#
# steepfell: folds
#
# jjpokerfun: raises $0.20 to $0.30
#
# DiarioMan: raises $0.70 to $1
#
# aspire8_svk: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.70) returned to DiarioMan
#
# DiarioMan collected $0.70 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.70 | Rake $0
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (button) folded before Flop
#
# Seat 4: DiarioMan (small blind) collected ($0.70)
#
# Seat 5: aspire8_svk (big blind) folded before Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: steepfell ($17.16 in chips)
#
# Seat 2: jjpokerfun ($11.08 in chips)
#
# Seat 4: DiarioMan ($29.61 in chips)
#
# Seat 5: aspire8_svk ($10 in chips)
#
# Seat 6: Cendman ($19.61 in chips)
#
# aspire8_svk: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# xata2204: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Jc 6d]
#
# steepfell: folds
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# aspire8_svk: folds
#
# Cendman: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) collected ($0.25)
#
# Seat 5: aspire8_svk (small blind) folded before Flop
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: steepfell ($17.16 in chips)
#
# Seat 2: jjpokerfun ($11.08 in chips)
#
# Seat 4: DiarioMan ($29.76 in chips)
#
# Seat 5: aspire8_svk ($10 in chips)
#
# Seat 6: Cendman ($19.51 in chips)
#
# Cendman: posts small blind $0.05
#
# steepfell: posts big blind $0.10
#
# xata2204: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [2s 7s]
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# aspire8_svk: raises $0.16 to $0.26
#
# Cendman: folds
#
# steepfell: calls $0.16
#
# *** FLOP *** [Ah 9c 5d]
#
# steepfell: checks
#
# aspire8_svk: bets $0.40
#
# steepfell: calls $0.40
#
# *** TURN *** [Ah 9c 5d] [3d]
#
# steepfell: checks
#
# aspire8_svk: bets $0.80
#
# steepfell: calls $0.80
#
# *** RIVER *** [Ah 9c 5d 3d] [2d]
#
# steepfell: checks
#
# aspire8_svk: bets $2
#
# steepfell: folds
#
# Uncalled bet ($2) returned to aspire8_svk
#
# aspire8_svk collected $2.84 from pot
#
# aspire8_svk: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $2.97 | Rake $0.13
#
# Board [Ah 9c 5d 3d 2d]
#
# Seat 1: steepfell (big blind) folded on the River
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk (button) collected ($2.84)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: steepfell ($15.70 in chips)
#
# Seat 2: jjpokerfun ($11.08 in chips)
#
# Seat 4: DiarioMan ($29.76 in chips)
#
# Seat 5: aspire8_svk ($11.38 in chips)
#
# Seat 6: Cendman ($19.46 in chips)
#
# steepfell: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# xata2204: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [6s Td]
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: raises $0.15 to $0.25
#
# jjpokerfun: folds
#
# Uncalled bet ($0.15) returned to steepfell
#
# steepfell collected $0.20 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.20 | Rake $0
#
# Seat 1: steepfell (small blind) collected ($0.20)
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: steepfell ($15.80 in chips)
#
# Seat 2: jjpokerfun ($10.98 in chips)
#
# Seat 3: xata2204 ($5.09 in chips)
#
# Seat 4: DiarioMan ($29.76 in chips)
#
# Seat 5: aspire8_svk ($11.38 in chips)
#
# Seat 6: Cendman ($19.46 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# xata2204: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Kd Qc]
#
# DiarioMan: folds
#
# aspire8_svk: raises $0.20 to $0.30
#
# Cendman: folds
#
# steepfell: folds
#
# jjpokerfun: raises $0.70 to $1
#
# xata2204 has timed out
#
# xata2204: folds
#
# aspire8_svk: calls $0.70
#
# *** FLOP *** [4c 4s 8s]
#
# jjpokerfun: bets $1.10
#
# aspire8_svk: folds
#
# Uncalled bet ($1.10) returned to jjpokerfun
#
# jjpokerfun collected $2.01 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $2.10 | Rake $0.09
#
# Board [4c 4s 8s]
#
# Seat 1: steepfell (button) folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (small blind) collected ($2.01)
#
# Seat 3: xata2204 (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk folded on the Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: steepfell ($15.80 in chips)
#
# Seat 2: jjpokerfun ($11.99 in chips)
#
# Seat 4: DiarioMan ($29.76 in chips)
#
# Seat 5: aspire8_svk ($10.38 in chips)
#
# Seat 6: Cendman ($19.46 in chips)
#
# DiarioMan: posts small blind $0.05
#
# aspire8_svk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Kh 5h]
#
# Cendman: folds
#
# steepfell: folds
#
# jjpokerfun: raises $0.20 to $0.30
#
# DiarioMan: folds
#
# aspire8_svk: calls $0.20
#
# *** FLOP *** [8s Kc 7s]
#
# aspire8_svk: checks
#
# jjpokerfun: bets $0.46
#
# aspire8_svk: calls $0.46
#
# *** TURN *** [8s Kc 7s] [4s]
#
# aspire8_svk: checks
#
# jjpokerfun: bets $0.82
#
# aspire8_svk: calls $0.82
#
# *** RIVER *** [8s Kc 7s 4s] [3s]
#
# aspire8_svk: checks
#
# jjpokerfun: checks
#
# *** SHOW DOWN ***
#
# aspire8_svk: shows [Ah Kd] (a pair of Kings)
#
# jjpokerfun: mucks hand
#
# aspire8_svk collected $3.07 from pot
#
# *** SUMMARY ***
#
# Total pot $3.21 | Rake $0.14
#
# Board [8s Kc 7s 4s 3s]
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (button) mucked [Kh 5h]
#
# Seat 4: DiarioMan (small blind) folded before Flop
#
# Seat 5: aspire8_svk (big blind) showed [Ah Kd] and won ($3.07) with a pair of Kings
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: steepfell ($15.80 in chips)
#
# Seat 2: jjpokerfun ($10.41 in chips)
#
# Seat 4: DiarioMan ($29.71 in chips)
#
# Seat 5: aspire8_svk ($11.87 in chips)
#
# Seat 6: Cendman ($19.46 in chips)
#
# aspire8_svk: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [9c Js]
#
# steepfell: folds
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# aspire8_svk: folds
#
# Cendman: calls $0.14
#
# *** FLOP *** [7d Ad Qs]
#
# Cendman: checks
#
# DiarioMan: bets $0.44
#
# Cendman: calls $0.44
#
# *** TURN *** [7d Ad Qs] [8s]
#
# Cendman: checks
#
# DiarioMan: bets $0.89
#
# Cendman: calls $0.89
#
# *** RIVER *** [7d Ad Qs 8s] [6c]
#
# Cendman: checks
#
# DiarioMan: checks
#
# *** SHOW DOWN ***
#
# Cendman: shows [Qd 9d] (a pair of Queens)
#
# DiarioMan: mucks hand
#
# Cendman collected $3.05 from pot
#
# *** SUMMARY ***
#
# Total pot $3.19 | Rake $0.14
#
# Board [7d Ad Qs 8s 6c]
#
# Seat 1: steepfell folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) mucked [Jd 3d]
#
# Seat 5: aspire8_svk (small blind) folded before Flop
#
# Seat 6: Cendman (big blind) showed [Qd 9d] and won ($3.05) with a pair of Queens
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: steepfell ($15.80 in chips)
#
# Seat 2: jjpokerfun ($10.41 in chips)
#
# Seat 4: DiarioMan ($28.14 in chips)
#
# Seat 5: aspire8_svk ($11.82 in chips)
#
# Seat 6: Cendman ($20.94 in chips)
#
# Cendman: posts small blind $0.05
#
# steepfell: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Qd 4d]
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Cendman: folds
#
# Uncalled bet ($0.05) returned to steepfell
#
# steepfell collected $0.10 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.10 | Rake $0
#
# Seat 1: steepfell (big blind) collected ($0.10)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk (button) folded before Flop (didn't bet)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: steepfell ($15.85 in chips)
#
# Seat 2: jjpokerfun ($10.41 in chips)
#
# Seat 4: DiarioMan ($28.14 in chips)
#
# Seat 5: aspire8_svk ($11.82 in chips)
#
# Seat 6: Cendman ($20.89 in chips)
#
# steepfell: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8s 5h]
#
# DiarioMan: folds
#
# aspire8_svk: folds
#
# Cendman: raises $0.20 to $0.30
#
# steepfell: calls $0.25
#
# jjpokerfun: folds
#
# *** FLOP *** [Jh 9d 6s]
#
# steepfell: checks
#
# Cendman: bets $0.50
#
# steepfell: raises $0.90 to $1.40
#
# Cendman: folds
#
# Uncalled bet ($0.90) returned to steepfell
#
# steepfell collected $1.62 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $1.70 | Rake $0.08
#
# Board [Jh 9d 6s]
#
# Seat 1: steepfell (small blind) collected ($1.62)
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman (button) folded on the Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: steepfell ($16.67 in chips)
#
# Seat 2: jjpokerfun ($10.31 in chips)
#
# Seat 4: DiarioMan ($28.14 in chips)
#
# Seat 5: aspire8_svk ($11.82 in chips)
#
# Seat 6: Cendman ($20.09 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Jc 7c]
#
# aspire8_svk: folds
#
# Cendman: folds
#
# steepfell: raises $0.12 to $0.22
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# Uncalled bet ($0.12) returned to steepfell
#
# steepfell collected $0.25 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell (button) collected ($0.25)
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) folded before Flop
#
# Seat 5: aspire8_svk folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: steepfell ($16.82 in chips)
#
# Seat 2: jjpokerfun ($10.26 in chips)
#
# Seat 4: DiarioMan ($28.04 in chips)
#
# Seat 6: Cendman ($20.09 in chips)
#
# DiarioMan: posts small blind $0.05
#
# aspire8_svk: is sitting out
#
# aspire8_svk leaves the table
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Th 2c]
#
# gareev-x joins the table at seat #5
#
# steepfell: raises $0.15 to $0.25
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# Cendman: folds
#
# Uncalled bet ($0.15) returned to steepfell
#
# steepfell collected $0.25 from pot
#
# steepfell: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: steepfell collected ($0.25)
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (small blind) folded before Flop
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 2: jjpokerfun ($10.26 in chips)
#
# Seat 4: DiarioMan ($27.99 in chips)
#
# Seat 6: Cendman ($19.99 in chips)
#
# gareev-x will be allowed to play after the button
#
# Cendman: posts small blind $0.05
#
# steepfell: is sitting out
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Td Qs]
#
# DiarioMan: raises $0.14 to $0.24
#
# Cendman: folds
#
# steepfell leaves the table
#
# jjpokerfun: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan (button) collected ($0.25)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 2: jjpokerfun ($10.16 in chips)
#
# Seat 4: DiarioMan ($28.14 in chips)
#
# Seat 6: Cendman ($19.94 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# gareev-x: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Td 3d]
#
# theblindmonk joins the table at seat #1
#
# Cendman: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.05) returned to DiarioMan
#
# DiarioMan collected $0.10 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.10 | Rake $0
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) collected ($0.10)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 2: jjpokerfun ($10.11 in chips)
#
# Seat 4: DiarioMan ($28.19 in chips)
#
# Seat 5: gareev-x ($10 in chips)
#
# Seat 6: Cendman ($19.94 in chips)
#
# DiarioMan: posts small blind $0.05
#
# gareev-x: posts big blind $0.10
#
# theblindmonk: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Kh 5h]
#
# Cendman: raises $0.20 to $0.30
#
# jjpokerfun: calls $0.30
#
# DiarioMan: folds
#
# gareev-x: folds
#
# *** FLOP *** [3h 7s 9d]
#
# gareev-x leaves the table
#
# corsi22 joins the table at seat #5
#
# corsi22 leaves the table
#
# Cendman: checks
#
# Jefexx1 joins the table at seat #5
#
# jjpokerfun: checks
#
# *** TURN *** [3h 7s 9d] [2h]
#
# Cendman: checks
#
# jjpokerfun: bets $0.54
# Cendman: folds
#
# Uncalled bet ($0.54) returned to jjpokerfun
#
# jjpokerfun collected $0.72 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.75 | Rake $0.03
#
# Board [3h 7s 9d 2h]
#
# Seat 2: jjpokerfun (button) collected ($0.72)
#
# Seat 4: DiarioMan (small blind) folded before Flop
#
# Seat 5: gareev-x (big blind) folded before Flop
#
# Seat 6: Cendman folded on the Turn
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($10.53 in chips)
#
# Seat 4: DiarioMan ($28.14 in chips)
#
# Seat 6: Cendman ($19.64 in chips)
#
# Jefexx1 will be allowed to play after the button
#
# Cendman: posts small blind $0.05
#
# theblindmonk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [5d Qs]
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# Cendman: folds
#
# Uncalled bet ($0.05) returned to theblindmonk
#
# theblindmonk collected $0.10 from pot
#
# theblindmonk: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.10 | Rake $0
#
# Seat 1: theblindmonk (big blind) collected ($0.10)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) folded before Flop (didn't bet)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: theblindmonk ($10.05 in chips)
#
# Seat 2: jjpokerfun ($10.53 in chips)
#
# Seat 4: DiarioMan ($28.14 in chips)
#
# Seat 6: Cendman ($19.59 in chips)
#
# theblindmonk: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# Jefexx1: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [5h Ks]
#
# DiarioMan: raises $0.19 to $0.29
#
# Cendman: folds
#
# theblindmonk: raises $0.68 to $0.97
#
# jjpokerfun: folds
#
# DiarioMan: calls $0.68
#
# *** FLOP *** [2h 8s Tc]
#
# theblindmonk: bets $0.97
#
# DiarioMan: calls $0.97
#
# *** TURN *** [2h 8s Tc] [Jd]
#
# theblindmonk: checks
#
# DiarioMan: checks
#
# *** RIVER *** [2h 8s Tc Jd] [Ah]
#
# theblindmonk: checks
#
# DiarioMan: bets $5.70
#
# theblindmonk: folds
#
# Uncalled bet ($5.70) returned to DiarioMan
#
# DiarioMan collected $3.80 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $3.98 | Rake $0.18
#
# Board [2h 8s Tc Jd Ah]
#
# Seat 1: theblindmonk (small blind) folded on the River
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan collected ($3.80)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($10.43 in chips)
#
# Seat 4: DiarioMan ($30 in chips)
#
# Seat 6: Cendman ($19.59 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# Jefexx1: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Jh 6h]
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: raises $0.20 to $0.30
#
# DiarioMan: raises $0.70 to $1
#
# jjpokerfun: folds
#
# Uncalled bet ($0.70) returned to DiarioMan
#
# DiarioMan collected $0.60 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.60 | Rake $0
#
# Seat 1: theblindmonk (button) folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) collected ($0.60)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($10.13 in chips)
#
# Seat 4: DiarioMan ($30.30 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.59 in chips)
#
# DiarioMan: posts small blind $0.05
#
# Jefexx1: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Jd 3h]
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# Jefexx1: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.20 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.20 | Rake $0
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (small blind) collected ($0.20)
#
# Seat 5: Jefexx1 (big blind) folded before Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($10.13 in chips)
#
# Seat 4: DiarioMan ($30.40 in chips)
#
# Seat 6: Cendman ($19.59 in chips)
#
# Cendman: posts small blind $0.05
#
# theblindmonk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [9d 8h]
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# Cendman: folds
#
# theblindmonk: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: theblindmonk (big blind) folded before Flop
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) collected ($0.25)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($10.13 in chips)
#
# Seat 4: DiarioMan ($30.55 in chips)
#
# Seat 6: Cendman ($19.54 in chips)
#
# theblindmonk: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [2c 5s]
#
# DiarioMan: raises $0.19 to $0.29
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.19) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: theblindmonk (small blind) folded before Flop
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan collected ($0.25)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($10.03 in chips)
#
# Seat 4: DiarioMan ($30.70 in chips)
#
# Seat 6: Cendman ($19.54 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# Jefexx1: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [6d 9d]
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: raises $0.20 to $0.30
#
# DiarioMan: calls $0.20
#
# *** FLOP *** [2h 5c Th]
#
# jjpokerfun: checks
#
# DiarioMan: checks
#
# *** TURN *** [2h 5c Th] [4d]
#
# jjpokerfun: checks
#
# DiarioMan: checks
#
# *** RIVER *** [2h 5c Th 4d] [7d]
#
# jjpokerfun: checks
#
# DiarioMan: checks
#
# *** SHOW DOWN ***
#
# jjpokerfun: shows [6d 9d] (high card Ten)
#
# DiarioMan: shows [6s 4s] (a pair of Fours)
#
# DiarioMan collected $0.57 from pot
#
# *** SUMMARY ***
#
# Total pot $0.60 | Rake $0.03
#
# Board [2h 5c Th 4d 7d]
#
# Seat 1: theblindmonk (button) folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (small blind) showed [6d 9d] and lost with high card Ten
#
# Seat 4: DiarioMan (big blind) showed [6s 4s] and won ($0.57) with a pair of Fours
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($9.73 in chips)
#
# Seat 4: DiarioMan ($30.97 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.54 in chips)
#
# DiarioMan: posts small blind $0.05
#
# Jefexx1: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8s Ah]
#
# Cendman: folds
#
# theblindmonk: raises $0.20 to $0.30
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# Jefexx1: calls $0.20
#
# *** FLOP *** [5s Qd 3c]
#
# Jefexx1: checks
#
# theblindmonk: bets $0.31
#
# Jefexx1: folds
#
# Uncalled bet ($0.31) returned to theblindmonk
#
# theblindmonk collected $0.62 from pot
#
# theblindmonk: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.65 | Rake $0.03
#
# Board [5s Qd 3c]
#
# Seat 1: theblindmonk collected ($0.62)
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (small blind) folded before Flop
#
# Seat 5: Jefexx1 (big blind) folded on the Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: theblindmonk ($10.32 in chips)
#
# Seat 2: jjpokerfun ($9.73 in chips)
#
# Seat 4: DiarioMan ($30.92 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.54 in chips)
#
# Jefexx1: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [2c 5d]
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# Jefexx1: folds
#
# Cendman: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) collected ($0.25)
#
# Seat 5: Jefexx1 (small blind) folded before Flop
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: theblindmonk ($10.32 in chips)
#
# Seat 2: jjpokerfun ($9.73 in chips)
#
# Seat 4: DiarioMan ($31.07 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.44 in chips)
#
# Cendman: posts small blind $0.05
#
# theblindmonk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8s Jc]
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.19 to $0.29
#
# Jefexx1: folds
#
# Cendman: folds
#
# theblindmonk: calls $0.19
#
# *** FLOP *** [5d 3c 7s]
#
# theblindmonk: checks
#
# DiarioMan: bets $0.52
#
# theblindmonk: folds
#
# Uncalled bet ($0.52) returned to DiarioMan
#
# DiarioMan collected $0.60 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.63 | Rake $0.03
#
# Board [5d 3c 7s]
#
# Seat 1: theblindmonk (big blind) folded on the Flop
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan collected ($0.60)
#
# Seat 5: Jefexx1 (button) folded before Flop (didn't bet)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: theblindmonk ($10.03 in chips)
#
# Seat 2: jjpokerfun ($9.73 in chips)
#
# Seat 4: DiarioMan ($31.38 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.39 in chips)
#
# theblindmonk: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [2c Kh]
#
# DiarioMan: raises $0.24 to $0.34
#
# Jefexx1: folds
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.24) returned to DiarioMan
#
# DiarioMan collected $0.25 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: theblindmonk (small blind) folded before Flop
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan collected ($0.25)
#
# Seat 5: Jefexx1 folded before Flop (didn't bet)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: theblindmonk ($10 in chips)
#
# Seat 2: jjpokerfun ($9.63 in chips)
#
# Seat 4: DiarioMan ($31.53 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.39 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [3s 4d]
#
# Jefexx1: folds
#
# Cendman: folds
#
# theblindmonk: raises $0.20 to $0.30
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.70 to $1
#
# theblindmonk: calls $0.70
#
# *** FLOP *** [8d 6s 7d]
#
# DiarioMan: bets $1.70
#
# theblindmonk: calls $1.70
#
# *** TURN *** [8d 6s 7d] [Jh]
#
# DiarioMan: checks
#
# theblindmonk: bets $1.82
#
# DiarioMan: folds
#
# Uncalled bet ($1.82) returned to theblindmonk
#
# theblindmonk collected $5.20 from pot
#
# theblindmonk: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $5.45 | Rake $0.25
#
# Board [8d 6s 7d Jh]
#
# Seat 1: theblindmonk (button) collected ($5.20)
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) folded on the Turn
#
# Seat 5: Jefexx1 folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: theblindmonk ($12.50 in chips)
#
# Seat 2: jjpokerfun ($9.58 in chips)
#
# Seat 4: DiarioMan ($28.83 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.39 in chips)
#
# DiarioMan: posts small blind $0.05
#
# Jefexx1: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Qc Kc]
#
# Cendman: raises $0.20 to $0.30
#
# theblindmonk: folds
#
# jjpokerfun: calls $0.30
#
# DiarioMan: folds
#
# Jefexx1: folds
#
# *** FLOP *** [5s 9c 2s]
#
# Cendman: checks
#
# jjpokerfun: checks
#
# *** TURN *** [5s 9c 2s] [Ks]
#
# Cendman: checks
#
# jjpokerfun: bets $0.54
#
# Cendman: folds
#
# Uncalled bet ($0.54) returned to jjpokerfun
#
# jjpokerfun collected $0.72 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.75 | Rake $0.03
#
# Board [5s 9c 2s Ks]
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (button) collected ($0.72)
#
# Seat 4: DiarioMan (small blind) folded before Flop
#
# Seat 5: Jefexx1 (big blind) folded before Flop
#
# Seat 6: Cendman folded on the Turn
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: theblindmonk ($12.50 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 4: DiarioMan ($28.78 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($19.09 in chips)
#
# Jefexx1: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [6s Ks]
#
# theblindmonk: raises $0.20 to $0.30
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# Jefexx1: raises $0.70 to $1
#
# Cendman: calls $0.90
#
# theblindmonk: folds
#
# *** FLOP *** [7s 3s 9c]
#
# Jefexx1: bets $1.16
#
# Cendman: folds
#
# Uncalled bet ($1.16) returned to Jefexx1
#
# Jefexx1 collected $2.20 from pot
#
# Jefexx1: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $2.30 | Rake $0.10
#
# Board [7s 3s 9c]
#
# Seat 1: theblindmonk folded before Flop
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 (small blind) collected ($2.20)
#
# Seat 6: Cendman (big blind) folded on the Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: theblindmonk ($12.20 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 4: DiarioMan ($28.78 in chips)
#
# Seat 5: Jefexx1 ($11.20 in chips)
#
# Seat 6: Cendman ($18.09 in chips)
#
# Cendman: posts small blind $0.05
#
# theblindmonk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Jc Ks]
#
# jjpokerfun: folds
#
# DiarioMan: folds
#
# Jefexx1: folds
#
# Cendman: folds
#
# Uncalled bet ($0.05) returned to theblindmonk
#
# theblindmonk collected $0.10 from pot
#
# theblindmonk: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.10 | Rake $0
#
# Seat 1: theblindmonk (big blind) collected ($0.10)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 (button) folded before Flop (didn't bet)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: theblindmonk ($12.25 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 4: DiarioMan ($28.78 in chips)
#
# Seat 5: Jefexx1 ($11.20 in chips)
#
# Seat 6: Cendman ($18.04 in chips)
#
# theblindmonk: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [9d Qd]
#
# DiarioMan: folds
#
# Jefexx1: raises $0.10 to $0.20
#
# Cendman: folds
#
# theblindmonk: raises $0.60 to $0.80
#
# jjpokerfun: folds
#
# Jefexx1: calls $0.60
#
# *** FLOP *** [Kh Kc 2c]
#
# theblindmonk: bets $0.81
#
# Jefexx1: folds
#
# Uncalled bet ($0.81) returned to theblindmonk
#
# theblindmonk collected $1.62 from pot
#
# theblindmonk: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $1.70 | Rake $0.08
#
# Board [Kh Kc 2c]
#
# Seat 1: theblindmonk (small blind) collected ($1.62)
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 folded on the Flop
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: theblindmonk ($13.07 in chips)
#
# Seat 2: jjpokerfun ($9.90 in chips)
#
# Seat 4: DiarioMan ($28.78 in chips)
#
# Seat 5: Jefexx1 ($10.40 in chips)
#
# Seat 6: Cendman ($18.04 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# xata2204 was removed from the table for failing to post
#
# DiarioMan: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [As 3h]
#
# gareev-x joins the table at seat #3
#
# Jefexx1: folds
#
# Cendman: folds
#
# theblindmonk: raises $0.20 to $0.30
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.70 to $1
#
# theblindmonk: calls $0.70
#
# *** FLOP *** [9d Jh 5d]
#
# DiarioMan: bets $1.70
#
# theblindmonk: calls $1.70
#
# *** TURN *** [9d Jh 5d] [7s]
#
# DiarioMan: bets $2.86
#
# theblindmonk: folds
#
# Uncalled bet ($2.86) returned to DiarioMan
#
# DiarioMan collected $5.20 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $5.45 | Rake $0.25
#
# Board [9d Jh 5d 7s]
#
# Seat 1: theblindmonk (button) folded on the Turn
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) collected ($5.20)
#
# Seat 5: Jefexx1 folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: theblindmonk ($10.37 in chips)
#
# Seat 2: jjpokerfun ($9.85 in chips)
#
# Seat 4: DiarioMan ($31.28 in chips)
#
# Seat 5: Jefexx1 ($10.40 in chips)
#
# Seat 6: Cendman ($18.04 in chips)
#
# gareev-x will be allowed to play after the button
#
# DiarioMan: posts small blind $0.05
#
# Jefexx1: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [9h Td]
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# Jefexx1: calls $0.14
#
# *** FLOP *** [Qh 7s 5c]
#
# DiarioMan: checks
#
# Jefexx1: bets $0.24
#
# DiarioMan: folds
#
# Uncalled bet ($0.24) returned to Jefexx1
#
# Jefexx1 collected $0.46 from pot
#
# Jefexx1: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.48 | Rake $0.02
#
# Board [Qh 7s 5c]
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (small blind) folded on the Flop
#
# Seat 5: Jefexx1 (big blind) collected ($0.46)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: theblindmonk ($10.37 in chips)
#
# Seat 2: jjpokerfun ($9.85 in chips)
#
# Seat 4: DiarioMan ($31.04 in chips)
#
# Seat 5: Jefexx1 ($10.62 in chips)
#
# Seat 6: Cendman ($18.04 in chips)
#
# Jefexx1: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# gareev-x: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [7d 7c]
#
# theblindmonk: folds
#
# jjpokerfun: raises $0.20 to $0.30
#
# DiarioMan: folds
#
# Jefexx1: folds
#
# Cendman: folds
#
# Uncalled bet ($0.20) returned to jjpokerfun
#
# jjpokerfun collected $0.25 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun collected ($0.25)
#
# Seat 4: DiarioMan (button) folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 (small blind) folded before Flop
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: theblindmonk ($10.37 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 4: DiarioMan ($31.04 in chips)
#
# Seat 5: Jefexx1 ($10.57 in chips)
#
# Seat 6: Cendman ($17.94 in chips)
#
# Cendman: posts small blind $0.05
#
# theblindmonk: posts big blind $0.10
#
# gareev-x: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Th 3d]
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.19 to $0.29
#
# Jefexx1: raises $0.67 to $0.96
#
# Cendman: folds
#
# theblindmonk: folds
#
# DiarioMan: folds
#
# Uncalled bet ($0.67) returned to Jefexx1
#
# Jefexx1 collected $0.73 from pot
#
# Jefexx1: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.73 | Rake $0
#
# Seat 1: theblindmonk (big blind) folded before Flop
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan folded before Flop
#
# Seat 5: Jefexx1 (button) collected ($0.73)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: theblindmonk ($10.27 in chips)
#
# Seat 2: jjpokerfun ($10 in chips)
#
# Seat 4: DiarioMan ($30.75 in chips)
#
# Seat 5: Jefexx1 ($11.01 in chips)
#
# Seat 6: Cendman ($17.89 in chips)
#
# theblindmonk: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# gareev-x: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Th 5c]
#
# DiarioMan: folds
#
# Jefexx1: raises $0.10 to $0.20
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.10) returned to Jefexx1
#
# Jefexx1 collected $0.25 from pot
#
# Jefexx1: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: theblindmonk (small blind) folded before Flop
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 collected ($0.25)
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: theblindmonk ($10.22 in chips)
#
# Seat 2: jjpokerfun ($9.90 in chips)
#
# Seat 3: gareev-x ($10 in chips)
#
# Seat 4: DiarioMan ($30.75 in chips)
#
# Seat 5: Jefexx1 ($11.16 in chips)
#
# Seat 6: Cendman ($17.89 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# gareev-x: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Jd Ad]
#
# DiarioMan: folds
#
# Jefexx1: raises $0.10 to $0.20
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: raises $0.80 to $1
#
# gareev-x: folds
#
# Jefexx1: calls $0.80
#
# *** FLOP *** [3s 5c 2s]
#
# jjpokerfun: bets $1.10
#
# Jefexx1: folds
#
# Uncalled bet ($1.10) returned to jjpokerfun
#
# jjpokerfun collected $2.01 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $2.10 | Rake $0.09
#
# Board [3s 5c 2s]
#
# Seat 1: theblindmonk (button) folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (small blind) collected ($2.01)
#
# Seat 3: gareev-x (big blind) folded before Flop
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 folded on the Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: theblindmonk ($10.22 in chips)
#
# Seat 2: jjpokerfun ($10.91 in chips)
#
# Seat 3: gareev-x ($10 in chips)
#
# Seat 4: DiarioMan ($30.75 in chips)
#
# Seat 5: Jefexx1 ($10.16 in chips)
#
# Seat 6: Cendman ($17.89 in chips)
#
# gareev-x: posts small blind $0.05
#
# DiarioMan: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [7c Jd]
#
# Jefexx1: folds
#
# Cendman: raises $0.20 to $0.30
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# gareev-x: folds
#
# DiarioMan: folds
#
# Uncalled bet ($0.20) returned to Cendman
#
# Cendman collected $0.25 from pot
#
# Cendman: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 3: gareev-x (small blind) folded before Flop
#
# Seat 4: DiarioMan (big blind) folded before Flop
#
# Seat 5: Jefexx1 folded before Flop (didn't bet)
#
# Seat 6: Cendman collected ($0.25)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #3 is the button
#
# Seat 1: theblindmonk ($10.22 in chips)
#
# Seat 2: jjpokerfun ($10.91 in chips)
#
# Seat 3: gareev-x ($10 in chips)
#
# Seat 4: DiarioMan ($30.65 in chips)
#
# Seat 5: Jefexx1 ($10.16 in chips)
#
# Seat 6: Cendman ($18.04 in chips)
#
# DiarioMan: posts small blind $0.05
#
# Jefexx1: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8s 5d]
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# gareev-x: folds
#
# gareev-x leaves the table
#
# DiarioMan: raises $0.14 to $0.24
#
# Jefexx1: folds
#
# Uncalled bet ($0.14) returned to DiarioMan
#
# DiarioMan collected $0.20 from pot
#
# DiarioMan: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.20 | Rake $0
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 3: gareev-x (button) folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (small blind) collected ($0.20)
#
# Seat 5: Jefexx1 (big blind) folded before Flop
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #4 is the button
#
# Seat 1: theblindmonk ($10.22 in chips)
#
# Seat 2: jjpokerfun ($10.91 in chips)
#
# Seat 4: DiarioMan ($30.75 in chips)
#
# Seat 5: Jefexx1 ($10.06 in chips)
#
# Seat 6: Cendman ($18.04 in chips)
#
# Jefexx1: posts small blind $0.05
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8d 5c]
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# DiarioMan: raises $0.14 to $0.24
#
# Jefexx1: calls $0.19
#
# Cendman: folds
#
# *** FLOP *** [6d 7s Ts]
#
# Jefexx1: checks
#
# DiarioMan: checks
#
# *** TURN *** [6d 7s Ts] [5d]
#
# Jefexx1: bets $0.29
#
# DiarioMan: folds
#
# Uncalled bet ($0.29) returned to Jefexx1
#
# Jefexx1 collected $0.55 from pot
#
# Jefexx1: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.58 | Rake $0.03
#
# Board [6d 7s Ts 5d]
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun folded before Flop (didn't bet)
#
# Seat 4: DiarioMan (button) folded on the Turn
#
# Seat 5: Jefexx1 (small blind) collected ($0.55)
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #5 is the button
#
# Seat 1: theblindmonk ($10.22 in chips)
#
# Seat 2: jjpokerfun ($10.91 in chips)
#
# Seat 4: DiarioMan ($30.51 in chips)
#
# Seat 5: Jefexx1 ($10.37 in chips)
#
# Seat 6: Cendman ($17.94 in chips)
#
# Cendman: posts small blind $0.05
#
# theblindmonk: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Jd Jc]
#
# jjpokerfun: raises $0.20 to $0.30
#
# alezandrik joins the table at seat #3
#
# DiarioMan: raises $0.60 to $0.90
#
# Jefexx1: calls $0.90
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: calls $0.60
#
# *** FLOP *** [Jh 7s 3s]
#
# jjpokerfun: checks
#
# DiarioMan: bets $2.36
#
# Jefexx1: folds
#
# jjpokerfun: raises $2.90 to $5.26
#
# DiarioMan: folds
#
# Uncalled bet ($2.90) returned to jjpokerfun
#
# jjpokerfun collected $7.23 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $7.57 | Rake $0.34
#
# Board [Jh 7s 3s]
#
# Seat 1: theblindmonk (big blind) folded before Flop
#
# Seat 2: jjpokerfun collected ($7.23)
#
# Seat 4: DiarioMan folded on the Flop
#
# Seat 5: Jefexx1 (button) folded on the Flop
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 1: theblindmonk ($10.12 in chips)
#
# Seat 2: jjpokerfun ($14.88 in chips)
#
# Seat 4: DiarioMan ($27.25 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($17.89 in chips)
#
# theblindmonk: posts small blind $0.05
#
# jjpokerfun: posts big blind $0.10
#
# alezandrik: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [5h 8h]
#
# DiarioMan: folds
#
# Jefexx1: raises $0.13 to $0.23
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: calls $0.13
#
# *** FLOP *** [Kd Jh 8d]
#
# jjpokerfun: checks
#
# Jefexx1: checks
#
# *** TURN *** [Kd Jh 8d] [8s]
#
# jjpokerfun: bets $0.36
#
# Jefexx1: folds
#
# Uncalled bet ($0.36) returned to jjpokerfun
#
# jjpokerfun collected $0.49 from pot
#
# jjpokerfun: doesn't show hand
#
# *** SUMMARY ***
#
# Total pot $0.51 | Rake $0.02
#
# Board [Kd Jh 8d 8s]
#
# Seat 1: theblindmonk (small blind) folded before Flop
#
# Seat 2: jjpokerfun (big blind) collected ($0.49)
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 folded on the Turn
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #1 is the button
#
# Seat 1: theblindmonk ($10.07 in chips)
#
# Seat 2: jjpokerfun ($15.14 in chips)
#
# Seat 3: alezandrik ($10 in chips)
#
# Seat 4: DiarioMan ($27.25 in chips)
#
# Seat 5: Jefexx1 ($10 in chips)
#
# Seat 6: Cendman ($17.89 in chips)
#
# jjpokerfun: posts small blind $0.05
#
# alezandrik: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8c Jd]
#
# DiarioMan: folds
#
# Jefexx1: folds
#
# Cendman: folds
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.05) returned to alezandrik
#
# alezandrik collected $0.10 from pot
#
# *** SUMMARY ***
#
# Total pot $0.10 | Rake $0
#
# Seat 1: theblindmonk (button) folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (small blind) folded before Flop
#
# Seat 3: alezandrik (big blind) collected ($0.10)
#
# Seat 4: DiarioMan folded before Flop (didn't bet)
#
# Seat 5: Jefexx1 folded before Flop (didn't bet)
#
# Seat 6: Cendman folded before Flop (didn't bet)
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #2 is the button
#
# Seat 1: theblindmonk ($10.07 in chips)
#
# Seat 2: jjpokerfun ($15.09 in chips)
#
# Seat 3: alezandrik ($10.05 in chips)
#
# Seat 6: Cendman ($17.89 in chips)
#
# alezandrik: posts small blind $0.05
#
# DiarioMan: is sitting out
#
# Jefexx1: is sitting out
#
# Cendman: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [Tc 2d]
#
# DiarioMan leaves the table
#
# theblindmonk: folds
#
# jjpokerfun: folds
#
# mevvadim joins the table at seat #4
#
# mevvadim leaves the table
#
# alezandrik: raises $0.20 to $0.30
#
# Johi4321 joins the table at seat #4
#
# Cendman: folds
#
# Uncalled bet ($0.20) returned to alezandrik
#
# alezandrik collected $0.20 from pot
#
# *** SUMMARY ***
#
# Total pot $0.20 | Rake $0
#
# Seat 1: theblindmonk folded before Flop (didn't bet)
#
# Seat 2: jjpokerfun (button) folded before Flop (didn't bet)
#
# Seat 3: alezandrik (small blind) collected ($0.20)
#
# Seat 6: Cendman (big blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #3 is the button
#
# Seat 2: jjpokerfun ($15.09 in chips)
#
# Seat 3: alezandrik ($10.15 in chips)
#
# Seat 6: Cendman ($17.79 in chips)
#
# Johi4321 will be allowed to play after the button
#
# Cendman: posts small blind $0.05
#
# theblindmonk: is sitting out
#
# jjpokerfun: posts big blind $0.10
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [3s 4d]
#
# alezandrik: raises $0.15 to $0.25
#
# theblindmonk leaves the table
#
# Cendman: folds
#
# jjpokerfun: folds
#
# Uncalled bet ($0.15) returned to alezandrik
#
# alezandrik collected $0.25 from pot
#
# TheArnijs joins the table at seat #1
#
# *** SUMMARY ***
#
# Total pot $0.25 | Rake $0
#
# Seat 2: jjpokerfun (big blind) folded before Flop
#
# Seat 3: alezandrik (button) collected ($0.25)
#
# Seat 6: Cendman (small blind) folded before Flop
#
#
#
#
#
#
#
# false
# Table 'Adorea III' 6-max Seat #6 is the button
#
# Seat 2: jjpokerfun ($14.99 in chips)
#
# Seat 3: alezandrik ($10.30 in chips)
#
# Seat 6: Cendman ($17.74 in chips)
#
# TheArnijs will be allowed to play after the button
#
# jjpokerfun: posts small blind $0.05
#
# alezandrik: posts big blind $0.10
#
# Johi4321: sits out
#
# *** HOLE CARDS ***
#
# Dealt to jjpokerfun [8c 6h]
#
# Cendman: folds
#
# jjpokerfun: calls $0.05
#
# alezandrik: checks
#
# *** FLOP *** [3c 2d 6c]
#
# jjpokerfun: bets $0.14
#
# alezandrik: calls $0.14
#
# *** TURN *** [3c 2d 6c] [Kc]
#
# jjpokerfun: checks
#
# alezandrik: checks
#
# *** RIVER *** [3c 2d 6c Kc] [5d]
#
# jjpokerfun: checks
#
# alezandrik: checks
#
# *** SHOW DOWN ***
#
# jjpokerfun: shows [8c 6h] (a pair of Sixes)
#
# alezandrik: mucks hand
#
# jjpokerfun collected $0.46 from pot
#
# *** SUMMARY ***
#
# Total pot $0.48 | Rake $0.02
#
# Board [3c 2d 6c Kc 5d]
#
# Seat 2: jjpokerfun (small blind) showed [8c 6h] and won ($0.46) with a pair of Sixes
#
# Seat 3: alezandrik (big blind) mucked [3h 8d]
#
# Seat 6: Cendman (button) folded before Flop (didn't bet)

# %%
from poker.room.pokerstars import PokerStarsHandHistory
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-43de3c3151dd> in <module>()
# ----> 1 from poker.room.pokerstars import PokerStarsHandHistory
#
# C:\Users\jiafei.duan\AppData\Local\Continuum\Anaconda3\lib\site-packages\poker\__init__.py in <module>()
#       8
#       9 from poker._common import PokerEnum
# ---> 10 from poker.card import Suit, Rank, Card, FACE_RANKS, BROADWAY_RANKS
#      11 from poker.hand import Shape, Hand, Combo, Range, PAIR_HANDS, OFFSUIT_HANDS, SUITED_HANDS
#      12 from poker.constants import PokerRoom, Currency, Game, GameType, Limit, MoneyType, Action, Position
#
# C:\Users\jiafei.duan\AppData\Local\Continuum\Anaconda3\lib\site-packages\poker\card.py in <module>()
#      49
#      50
# ---> 51 FACE_RANKS = Rank('J'), Rank('Q'), Rank('K')
#      52
#      53 BROADWAY_RANKS = Rank('T'), Rank('J'), Rank('Q'), Rank('K'), Rank('A')
#
# C:\Users\jiafei.duan\AppData\Local\Continuum\Anaconda3\lib\enum.py in __call__(cls, value, names, module, qualname, type, start)
#     289         """
#     290         if names is None:  # simple value lookup
# --> 291             return cls.__new__(cls, value)
#     292         # otherwise, functional API: we're creating a new Enum type
#     293         return cls._create_(value, names, module=module, qualname=qualname, type=type, start=start)
#
# C:\Users\jiafei.duan\AppData\Local\Continuum\Anaconda3\lib\enum.py in __new__(cls, value)
#     531                     return member
#     532         # still not found -- try _missing_ hook
# --> 533         return cls._missing_(value)
#     534
#     535     def _generate_next_value_(name, start, count, last_values):
#
# C:\Users\jiafei.duan\AppData\Local\Continuum\Anaconda3\lib\enum.py in _missing_(cls, value)
#     544     @classmethod
#     545     def _missing_(cls, value):
# --> 546         raise ValueError("%r is not a valid %s" % (value, cls.__name__))
#     547
#     548     def __repr__(self):
#
# ValueError: 'J' is not a valid Rank

# %%
# !pip install poker
# Out:
# Requirement already satisfied: poker in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages
# Requirement already satisfied: cached-property in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: click in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: enum34 in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: python-dateutil in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: pathlib in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: parsedatetime in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: pytz in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: requests in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: configparser in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: lxml in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from poker)
# Requirement already satisfied: six>=1.5 in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from python-dateutil->poker)
# Requirement already satisfied: future in c:\users\jiafei.duan\appdata\local\continuum\anaconda3\lib\site-packages (from parsedatetime->poker)
